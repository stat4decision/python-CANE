# %% [markdown]
# # PANDAS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Définir un objet Series comprenant la population de 4 pays puis afficher les pays ayant une population > 50’000’000.

# %%
ser_pays=pd.Series([70,300,8,1400],index=["France","USA","Suisse","Chine"])

# %%
ser_pays[ser_pays>50]
# Out:
# France      70
# USA        300
# Chine     1400
# dtype: int64

# %%
#si on veut afficher les pays avec des populations entre 50 et 100M
ser_pays[(ser_pays>50)&(ser_pays<100)]
# Out:
# France    70
# dtype: int64

# %%
"France" in ser_pays
# Out:
# True

# %% [markdown]
# Définir les noms de l’objet et de la colonne des pays pour la Series précédente

# %%
ser_pays.name="Populations"
ser_pays.index.name="Pays"
ser_pays
# Out:
# Pays
# France      70
# USA        300
# Suisse       8
# Chine     1400
# Name: Populations, dtype: int64

# %% [markdown]
# Créez un objet Series et ajoutez des dates partant du 3 octobre 2017 par jour jusqu’à aujourd’hui.

# %%
import datetime
dates = pd.date_range(start="2017-10-03" , end=datetime.date.today(), freq="D")
ser_action=pd.Series(np.random.random(len(dates)), index=dates )

# %%
ser_action.shape
# Out:
# (190,)

# %%
ser_action.plot()

# %% [markdown]
# Créez un objet Series avec des résultats par trimestres à partir de 2012.

# %%
frame_global.Accepted_Personal_Loan
# Out:
# 0       F
# 1       F
# 2       F
# 3       F
# 4       F
# 5       T
# 6       F
# 7       F
# 8       F
# 9       F
# 10      F
# 11      F
# 12      T
# 13      F
# 14      F
# 15      F
# 16      F
# 17      T
# 18      F
# 19      F
# 20      F
# 21      F
# 22      F
# 23      F
# 24      F
# 25      T
# 26      F
# 27      F
# 28      F
# 29      F
#        ..
# 1970    F
# 1971    F
# 1972    F
# 1973    F
# 1974    T
# 1975    F
# 1976    F
# 1977    F
# 1978    F
# 1979    F
# 1980    T
# 1981    F
# 1982    F
# 1983    F
# 1984    F
# 1985    F
# 1986    F
# 1987    F
# 1988    F
# 1989    F
# 1990    F
# 1991    F
# 1992    T
# 1993    F
# 1994    F
# 1995    F
# 1996    T
# 1997    F
# 1998    F
# 1999    F
# Name: Accepted_Personal_Loan, Length: 2000, dtype: object

# %% [markdown]
# Récupérez les données de Wikipédia sur les résultats de NBA et obtenir les statistiques descriptives pour les variables quantitatives.
# On utilisera plutôt Chrome ou Firefox pour ce type de tâches (éviter IE)

# %%
import webbrowser
url='https://en.wikipedia.org/wiki/List_of_all-time_NBA_win-loss_records'
webbrowser.open(url)
# Out:
# True

# %%
frame_NBA=pd.read_clipboard()

# %%
frame_NBA.head()
# Out:
#    Rank                   Team    Won   Lost   Pct. First NBA season  \
# 0     1      San Antonio Spurs  2,067  1,247  0.624          1976–77
# 1     2     Los Angeles Lakers  3,261  2,190  0.598          1948–49
# 2     3         Boston Celtics  3,274  2,286  0.589          1946–47
# 3     4           Phoenix Suns  2,146  1,824  0.541          1968–69
# 4     5  Oklahoma City Thunder  2,186  1,866  0.539          1967–68
#
#   Total games   Division
# 0       3,314  Southwest
# 1       5,451    Pacific
# 2       5,560   Atlantic
# 3       3,970    Pacific
# 4       4,052  Northwest

# %%
frame_NBA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
# Rank                30 non-null int64
# Team                30 non-null object
# Won                 30 non-null object
# Lost                30 non-null object
# Pct.                30 non-null float64
# First NBA season    30 non-null object
# Total games         30 non-null object
# Division            30 non-null object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.0+ KB

# %%
frame_NBA.columns
# Out:
# Index(['Rank', 'Team', 'Won', 'Lost', 'Pct.', 'First NBA season',
#        'Total games', 'Division'],
#       dtype='object')

# %% [markdown]
# On voit que certaines colonnes sont mal codées :
#     - les virgules sont en fait des séparateurs de milliers

# %%
frame_NBA["Won"]
frame_NBA.Won
# Out:
# 0     3,314
# 1     5,451
# 2     5,560
# 3     3,970
# 4     4,052
# 5     3,478
# 6     3,806
# 7     4,133
# 8     4,052
# 9     2,330
# 10    5,386
# 11    3,970
# 12    2,986
# 13    5,388
# 14    3,313
# 15    5,557
# 16    5,450
# 17    2,248
# 18    3,314
# 19    5,556
# 20    3,806
# 21    1,214
# 22    5,451
# 23    4,533
# 24    1,756
# 25    2,166
# 26    1,756
# 27    3,314
# 28    3,806
# 29    2,248
# Name: Total games, dtype: object

# %%
frame_NBA[["Won","Lost"]]
# Out:
#       Won   Lost
# 0   2,067  1,247
# 1   3,261  2,190
# 2   3,274  2,286
# 3   2,146  1,824
# 4   2,186  1,866
# 5   1,866  1,612
# 6   2,032  1,774
# 7   2,156  1,977
# 8   2,107  1,945
# 9   1,211  1,119
# 10  2,754  2,632
# 11  2,025  1,945
# 12  1,515  1,471
# 13  2,693  2,695
# 14  1,648  1,665
# 15  2,732  2,825
# 16  2,653  2,797
# 17  1,091  1,157
# 18  1,603  1,711
# 19  2,657  2,899
# 20  1,779  2,027
# 21    562    652
# 22  2,496  2,955
# 23  2,053  2,480
# 24    785    971
# 25    952  1,214
# 26    737  1,019
# 27  1,380  1,934
# 28  1,520  2,286
# 29    878  1,370

# %%
frame_NBA[frame_NBA["Division"]=="Southwest"]
# Out:
#     Rank                  Team    Won   Lost   Pct. First NBA season  \
# 0      1     San Antonio Spurs  2,067  1,247  0.624          1976–77
# 8      9       Houston Rockets  2,107  1,945  0.520          1967–68
# 12    13      Dallas Mavericks  1,515  1,471  0.507          1980–81
# 21    22  New Orleans Pelicans    562    652  0.463       2002–03[a]
# 26    27     Memphis Grizzlies    737  1,019  0.420          1995–96
#
#    Total games   Division
# 0        3,314  Southwest
# 8        4,052  Southwest
# 12       2,986  Southwest
# 21       1,214  Southwest
# 26       1,756  Southwest

# %%
def nettoyage(frame):
    """Nettoyage de mon dataframe"""
    for col in frame.columns:
        if frame[col].dtype==object:
            frame[col]=pd.to_numeric(frame[col].str.replace(",",""),errors="ignore")
    return frame

# %%
frame_nba2=nettoyage(frame_NBA)

# %%
frame_nba2["First NBA season"]=pd.to_numeric(frame_nba2["First NBA season"].str[:4])

# %%
frame_nba2["Age de l'équipe"]=2018-frame_nba2["First NBA season"]

# %%
frame_nba2
# Out:
#     Rank                    Team   Won  Lost   Pct.  First NBA season  \
# 0      1       San Antonio Spurs  2067  1247  0.624              1976
# 1      2      Los Angeles Lakers  3261  2190  0.598              1948
# 2      3          Boston Celtics  3274  2286  0.589              1946
# 3      4            Phoenix Suns  2146  1824  0.541              1968
# 4      5   Oklahoma City Thunder  2186  1866  0.539              1967
# 5      6               Utah Jazz  1866  1612  0.537              1974
# 6      7  Portland Trail Blazers  2032  1774  0.534              1970
# 7      8           Chicago Bulls  2156  1977  0.522              1966
# 8      9         Houston Rockets  2107  1945  0.520              1967
# 9     10              Miami Heat  1211  1119  0.520              1988
# 10    11      Philadelphia 76ers  2754  2632  0.511              1949
# 11    12         Milwaukee Bucks  2025  1945  0.510              1968
# ...

# %% [markdown]
# Trier les données NBA en fonction de la variable Pct.

# %%
frame_nba2.describe(include="all")
# Out:
#              Rank                   Team          Won         Lost       Pct.  \
# count   30.000000                     30    30.000000    30.000000  30.000000
# unique        NaN                     30          NaN          NaN        NaN
# top           NaN  Golden State Warriors          NaN          NaN        NaN
# freq          NaN                      1          NaN          NaN        NaN
# mean    15.500000                    NaN  1893.966667  1884.833333   0.494300
# std      8.803408                    NaN   738.329311   632.328051   0.055334
# min      1.000000                    NaN   562.000000   652.000000   0.391000
# 25%      8.250000                    NaN  1413.750000  1395.250000   0.459250
# 50%     15.500000                    NaN  2028.500000  1900.000000   0.494500
# 75%     22.750000                    NaN  2418.500000  2286.000000   0.521500
# max     30.000000                    NaN  3274.000000  2955.000000   0.624000
#
# ...

# %%
frame_resultats=frame_nba2.agg(["mean","std","median"])

# %%
frame_resultats["Won"]
# Out:
# mean      1893.966667
# std        738.329311
# median    2028.500000
# Name: Won, dtype: float64

# %%
#.loc permet de travailler sur les index
frame_nba2.loc[2,"Team"]
# Out:
# 'Boston Celtics'

# %%
#.iloc permet de travailler sur les positions
frame_nba2.iloc[2,1]
# Out:
# 'Boston Celtics'

# %% [markdown]
# Importez le fichier demo_ventes.csv depuis Python dans titanic train.

# %%
csv_data=pd.read_csv("../data/demo_ventes.csv",sep=";")

# %%
csv_data
# Out:
#     account     Jan     Feb     Mar
# 0    211829   10000   62000   35000
# 1    320563   95000   45000   35000
# 2    648336   91000  120000   35000
# 3    109996   45000  120000   10000
# 4    121213  162000  120000   35000
# 5    132971  150000  120000   35000
# 6    145068   62000  120000   70000
# 7    205217  145000   95000   35000
# 8    209744   70000   95000   35000
# 9    212303   70000  120000   35000
# 10   214098   45000  120000   55000
# 11   231907  150000   10000  162000
# 12   242368  162000  120000   35000
# 13   268755   55000  120000   35000
# 14   273274  150000  120000   70000

# %% [markdown]
# Importez un tableau en html depuis la page <br>
# http://www.fdic.gov/bank/individual/failed/banklist.html

# %%
bank=pd.read_html("http://www.fdic.gov/bank/individual/failed/banklist.html")

# %%
frame_bank=bank[0]

# %%
NBA=pd.read_html('https://en.wikipedia.org/wiki/List_of_all-time_NBA_win-loss_records',
                header="infer")

# %%
NBA[1]
# Out:
#     Rank                    Team   Won  Lost   Pct. First NBA season  \
# 0      1       San Antonio Spurs  2067  1247  0.624          1976–77
# 1      2      Los Angeles Lakers  3261  2190  0.598          1948–49
# 2      3          Boston Celtics  3274  2286  0.589          1946–47
# 3      4            Phoenix Suns  2146  1824  0.541          1968–69
# 4      5   Oklahoma City Thunder  2186  1866  0.539          1967–68
# 5      6               Utah Jazz  1866  1612  0.537          1974–75
# 6      7  Portland Trail Blazers  2032  1774  0.534          1970–71
# 7      8           Chicago Bulls  2156  1977  0.522          1966–67
# 8      9         Houston Rockets  2107  1945  0.520          1967–68
# 9     10              Miami Heat  1211  1119  0.520          1988–89
# 10    11      Philadelphia 76ers  2754  2632  0.511          1949–50
# 11    12         Milwaukee Bucks  2025  1945  0.510          1968–69
# 12    13        Dallas Mavericks  1515  1471  0.507          1980–81
# ...

# %% [markdown]
# Importez un fichier Excel depuis python. On utilisera excel-data.xlsx et Presidentielle_2017_Resultats_Communes_Tour_1.xls
#
# On a deux approches :
# - avec pd.read_excel en connaissant la feuille qui nous intéresse
# - avec pd.ExcelFile afin de créer un objet dans lequel on pourra avoir toutes les feuilles

# %%
frame_exce1=pd.read_excel("../data/excel-data.xlsx")

# %%
classeur_excel=pd.ExcelFile("../data/credit2.xlsx")

# %%
classeur_excel.sheet_names
# Out:
# ['Sheet1']

# %%
frame_credit=classeur_excel.parse('Sheet1')

# %%
frame_credit.shape
# Out:
# (2000, 10)

# %% [markdown]
# Importez la base de données SQLite salaries et récupérez la table Salaries dans un DataFrame

# %%
from sqlalchemy import create_engine

# %%
con=create_engine("sqlite:///../data/Salaries.sqlite")

# %%
con.table_names()
# Out:
# ['Salaries']

# %%
frame_salaries=pd.read_sql_query("select * from Salaries",con=con)

# %%
frame_salaries
# Out:
#             Id            EmployeeName  \
# 0            1          NATHANIEL FORD
# 1            2            GARY JIMENEZ
# 2            3          ALBERT PARDINI
# 3            4       CHRISTOPHER CHONG
# 4            5         PATRICK GARDNER
# 5            6          DAVID SULLIVAN
# 6            7               ALSON LEE
# 7            8           DAVID KUSHNER
# 8            9          MICHAEL MORRIS
# 9           10      JOANNE HAYES-WHITE
# 10          11           ARTHUR KENNEY
# 11          12        PATRICIA JACKSON
# 12          13       EDWARD HARRINGTON
# 13          14             JOHN MARTIN
# 14          15          DAVID FRANKLIN
# 15          16         RICHARD CORRIEA
# 16          17                AMY HART
# 17          18          SEBASTIAN WONG
# 18          19              MARTY ROSS
# 19          20           ELLEN MOFFATT
# 20          21              VENUS AZAR
# 21          22            JUDY MELINEK
# 22          23           GEORGE GARCIA
# ...

# %% [markdown]
# Joindre les deux dataframes de ventes en utilisant l’id.

# %%
frame_credit2=pd.read_table("../data/credit1.txt")

# %%
frame_credit2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 22 columns):
# Months_as_a_Customer              2000 non-null int64
# Number_of_Products                2000 non-null int64
# RFM_Score                         2000 non-null int64
# Average_Balance_Feed_Index        2000 non-null int64
# Number_of_Transactions            2000 non-null int64
# Personal_Debt_to_Equity_Ratio     2000 non-null int64
# Months_Current_Account            2000 non-null int64
# Number_of_Loan_Accounts           2000 non-null int64
# Customer_ID                       2000 non-null int64
# Has_Bad_Payment_Record            2000 non-null int64
# Members_Within_Household          2000 non-null int64
# Number_of_Call_Center_Contacts    2000 non-null int64
# Weeks_Since_Last_Offer            2000 non-null int64
# Accepted_Personal_Loan            2000 non-null object
# Accepted_Retention                2000 non-null object
# ...

# %%
frame_global=pd.merge(frame_credit,frame_credit2,on="Customer_ID")

# %%
frame_global.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 0 to 1999
# Data columns (total 31 columns):
# Age                                2000 non-null int64
# Gender                             2000 non-null object
# Marital_Status                     2000 non-null object
# Age_Youngest_Child                 2000 non-null int64
# Number_of_Workers_in_Household     2000 non-null int64
# Percentage_White_Collar_Workers    2000 non-null int64
# Household_Debt_to_Equity_Ratio     2000 non-null int64
# Income                             2000 non-null int64
# Homeowner                          2000 non-null object
# Customer_ID                        2000 non-null int64
# Months_as_a_Customer               2000 non-null int64
# Number_of_Products                 2000 non-null int64
# RFM_Score                          2000 non-null int64
# Average_Balance_Feed_Index         2000 non-null int64
# Number_of_Transactions             2000 non-null int64
# ...

# %%
frame_global["Age"].mean()
# Out:
# 39.4955

# %%
frame_global["Marital_Status"].value_counts(normalize=True)
# Out:
# S    0.4865
# M    0.2630
# U    0.2505
# Name: Marital_Status, dtype: float64

# %%
frame_global.pivot_table(values="Income",
                         index="Gender",columns=["Homeowner","Marital_Status"])
# Out:
# Homeowner                  F                                         T  \
# Marital_Status             M             S             U             M
# Gender
# F               49359.707447  49931.315789  50525.421053  49821.187500
# M               52531.046875  47666.947368  51703.481481  53559.658537
#
# Homeowner
# Marital_Status             S             U
# Gender
# F               50092.906040  50193.115942
# M               49105.884298  50391.236111

# %% [markdown]
# Créez une variable dans le dataframe des ventes pour obtenir des niveaux de ventes.

# %%
frame_global["Income2"]=frame_global["Income"]*2

# %%
#discretisation
frame_global["Income_disc"]=pd.cut(frame_global["Income"],5)
frame_global["Income_disc"].value_counts()
# Out:
# (42800.4, 55491.6]      810
# (55491.6, 68182.8]      522
# (30109.2, 42800.4]      476
# (68182.8, 80874.0]      116
# (17354.544, 30109.2]     76
# Name: Income_disc, dtype: int64

# %%
frame_global["Income_disc2"]=pd.cut(frame_global["Income"],[0,10000,50000,100000])
frame_global["Income_disc2"].value_counts()
# Out:
# (10000, 50000]     1028
# (50000, 100000]     972
# (0, 10000]            0
# Name: Income_disc2, dtype: int64

# %%
frame_global["Income_disc3"]=pd.qcut(frame_global["Income"],4,labels=["C1","C2","C3","C4"])
frame_global["Income_disc3"].value_counts().sort_index()
# Out:
# C1    500
# C2    500
# C3    502
# C4    498
# Name: Income_disc3, dtype: int64

# %%
frame_global.sort_values(["Gender","Income"],ascending=[True, False])
# Out:
#       Age Gender Marital_Status  Age_Youngest_Child  \
# 604    44      F              M                  15
# 293    23      F              S                   0
# 798    29      F              S                   0
# 618    48      F              U                  19
# 1584   44      F              M                  17
# 672    39      F              M                  12
# 196    51      F              S                  23
# 761    31      F              S                   2
# 1399   35      F              S                   2
# 1657   36      F              S                   2
# 367    54      F              U                  24
# 52     58      F              M                  28
# 770    35      F              M                   8
# 1699   57      F              U                  28
# 756    34      F              M                   2
# 302    38      F              U                  12
# 606    43      F              U                  12
# ...

# %% [markdown]
# ## GROUPBY

# %% [markdown]
# - Données sur les salaires
#
# - On utilise le groupby() pour rassembler les types d’emploi
#
# - Et on calcule des statistiques pour chaque type
#
# On peut utiliser la fonction .agg() avec par exemple ‘mean’ comme paramètre
#
# On utilise aussi fréquemment la fonction apply() combinée à une fonction lambda

# %%
group_gender=frame_global.groupby(["Gender"])

# %%
group_gender["Income"].agg(["mean","std"])
# Out:
#                 mean           std
# Gender
# F       49961.043744  10730.635157
# M       50174.591937  12222.261126

# %%
group_gender["Income"].apply(lambda x:x.max()-x.min())
# Out:
# Gender
# F    60208
# M    63229
# Name: Income, dtype: int64
